# %% [markdown]
# ## Week 11, Lab 1: SQL Practice
#
# > Author: Matt Brems

# %% [markdown]
# In this lab, you're going to have ten prompts. Each prompt will require you to do two things:
# 1. Write a SQL query.
# 2. Use the result of that query to answer the question.
#
# The purpose of this lab is to get you to practice your SQL - an **important** skill in data science! While it is possible to get these answers using Pandas, it should be your goal to do everything only in SQL.
#
# **Data**: The data used in this lab is the famous (but fake) Northwind database. It contains various tables of transactions. The schema for the Northwind database can be found [here](http://www.zentut.com/wp-content/uploads/downloads/2013/06/Northwind-Sample-Database-Diagram.pdf).

# %%
# Import Pandas and Create_Engine

import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgres://jlpmxjkftcsepc:bb9cd75e6659d7d67ee3b86be0f905069319c75bd6823d786c808dd799ea85a2@ec2-54-227-251-33.compute-1.amazonaws.com:5432/d9teltkv30dni7')

# %% [markdown]
# ### Prompt 1
#
# How many rows are there in the `customers` table of the Northwind database?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT *
FROM customers
"""

display(pd.read_sql_query(sql, engine))
engine.dispose()
# Out:
#    customer_id                          company_name             contact_name  \
# 0        ALFKI                   Alfreds Futterkiste             Maria Anders
# 1        ANATR    Ana Trujillo Emparedados y helados             Ana Trujillo
# 2        ANTON               Antonio Moreno Taquería           Antonio Moreno
# 3        AROUT                       Around the Horn             Thomas Hardy
# 4        BERGS                    Berglunds snabbköp       Christina Berglund
# 5        BLAUS               Blauer See Delikatessen               Hanna Moos
# 6        BLONP              Blondesddsl père et fils       Frédérique Citeaux
# 7        BOLID             Bólido Comidas preparadas            Martín Sommer
# 8        BONAP                              Bon app'         Laurence Lebihan
# 9        BOTTM                 Bottom-Dollar Markets        Elizabeth Lincoln
# 10       BSBEV                         B's Beverages        Victoria Ashworth
# 11       CACTU            Cactus Comidas para llevar         Patricio Simpson
# 12       CENTC            Centro comercial Moctezuma          Francisco Chang
# 13       CHOPS                     Chop-suey Chinese                Yang Wang
# 14       COMMI                      Comércio Mineiro             Pedro Afonso
# 15       CONSH                 Consolidated Holdings          Elizabeth Brown
# 16       DRACD              Drachenblut Delikatessen             Sven Ottlieb
# 17       DUMON                       Du monde entier           Janine Labrune
# 18       EASTC                    Eastern Connection                Ann Devon
# 19       ERNSH                          Ernst Handel            Roland Mendel
# 20       FAMIA                    Familia Arquibaldo                Aria Cruz
# 21       FISSA  FISSA Fabrica Inter. Salchichas S.A.               Diego Roel
# 22       FOLIG                     Folies gourmandes            Martine Rancé
# 23       FOLKO                        Folk och fä HB            Maria Larsson
# 24       FRANK                        Frankenversand            Peter Franken
# 25       FRANR                   France restauration           Carine Schmitt
# 26       FRANS                        Franchi S.p.A.            Paolo Accorti
# 27       FURIB        Furia Bacalhau e Frutos do Mar           Lino Rodriguez
# 28       GALED                Galería del gastrónomo         Eduardo Saavedra
# 29       GODOS                   Godos Cocina Típica        José Pedro Freyre
# ..         ...                                   ...                      ...
# 61       QUEEN                         Queen Cozinha           Lúcia Carvalho
# 62       QUICK                            QUICK-Stop              Horst Kloss
# 63       RANCH                         Rancho grande         Sergio Gutiérrez
# 64       RATTC            Rattlesnake Canyon Grocery             Paula Wilson
# 65       REGGC                    Reggiani Caseifici          Maurizio Moroni
# 66       RICAR                    Ricardo Adocicados           Janete Limeira
# 67       RICSU                    Richter Supermarkt             Michael Holz
# 68       ROMEY                      Romero y tomillo         Alejandra Camino
# 69       SANTG                         Santé Gourmet         Jonas Bergulfsen
# 70       SAVEA                    Save-a-lot Markets           Jose Pavarotti
# 71       SEVES                    Seven Seas Imports               Hari Kumar
# 72       SIMOB                         Simons bistro           Jytte Petersen
# 73       SPECD                  Spécialités du monde        Dominique Perrier
# 74       SPLIR                 Split Rail Beer & Ale       Art Braunschweiger
# 75       SUPRD                      Suprêmes délices         Pascale Cartrain
# 76       THEBI                        The Big Cheese                Liz Nixon
# 77       THECR                       The Cracker Box                 Liu Wong
# 78       TOMSP                    Toms Spezialitäten            Karin Josephs
# 79       TORTU                   Tortuga Restaurante     Miguel Angel Paolino
# 80       TRADH                Tradição Hipermercados        Anabela Domingues
# 81       TRAIH     Trail's Head Gourmet Provisioners           Helvetius Nagy
# 82       VAFFE                          Vaffeljernet              Palle Ibsen
# 83       VICTE                  Victuailles en stock             Mary Saveley
# 84       VINET             Vins et alcools Chevalier             Paul Henriot
# 85       WANDK                     Die Wandernde Kuh              Rita Müller
# 86       WARTH                        Wartian Herkku         Pirkko Koskitalo
# 87       WELLI                Wellington Importadora            Paula Parente
# 88       WHITC                  White Clover Markets           Karl Jablonski
# 89       WILMK                           Wilman Kala          Matti Karttunen
# 90       WOLZA                        Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                      contact_title                        address  \
# 0             Sales Representative                  Obere Str. 57
# 1                            Owner  Avda. de la Constitución 2222
# 2                            Owner                Mataderos  2312
# 3             Sales Representative                120 Hanover Sq.
# 4              Order Administrator                Berguvsvägen  8
# 5             Sales Representative                 Forsterstr. 57
# 6                Marketing Manager               24, place Kléber
# 7                            Owner                 C/ Araquil, 67
# 8                            Owner           12, rue des Bouchers
# 9               Accounting Manager             23 Tsawassen Blvd.
# 10            Sales Representative              Fauntleroy Circus
# 11                     Sales Agent                    Cerrito 333
# 12               Marketing Manager        Sierras de Granada 9993
# 13                           Owner                   Hauptstr. 29
# 14                 Sales Associate           Av. dos Lusíadas, 23
# 15            Sales Representative   Berkeley Gardens 12  Brewery
# 16             Order Administrator                   Walserweg 21
# 17                           Owner   67, rue des Cinquante Otages
# 18                     Sales Agent                 35 King George
# 19                   Sales Manager                   Kirchgasse 6
# 20             Marketing Assistant                   Rua Orós, 92
# 21              Accounting Manager             C/ Moralzarzal, 86
# 22           Assistant Sales Agent       184, chaussée de Tournai
# 23                           Owner                   Åkergatan 24
# 24               Marketing Manager              Berliner Platz 43
# 25               Marketing Manager                 54, rue Royale
# 26            Sales Representative            Via Monte Bianco 34
# 27                   Sales Manager         Jardim das rosas n. 32
# 28               Marketing Manager         Rambla de Cataluña, 23
# 29                   Sales Manager                  C/ Romero, 33
# ..                             ...                            ...
# 61             Marketing Assistant      Alameda dos Canàrios, 891
# 62              Accounting Manager               Taucherstraße 10
# 63            Sales Representative         Av. del Libertador 900
# 64  Assistant Sales Representative                2817 Milton Dr.
# 65                 Sales Associate         Strada Provinciale 124
# 66           Assistant Sales Agent            Av. Copacabana, 267
# 67                   Sales Manager              Grenzacherweg 237
# 68              Accounting Manager                    Gran Vía, 1
# 69                           Owner         Erling Skakkes gate 78
# 70            Sales Representative                187 Suffolk Ln.
# 71                   Sales Manager                90 Wadhurst Rd.
# 72                           Owner                   Vinbæltet 34
# 73               Marketing Manager              25, rue Lauriston
# 74                   Sales Manager                   P.O. Box 555
# 75              Accounting Manager           Boulevard Tirou, 255
# 76               Marketing Manager       89 Jefferson Way Suite 2
# 77             Marketing Assistant            55 Grizzly Peak Rd.
# 78               Marketing Manager                  Luisenstr. 48
# 79                           Owner               Avda. Azteca 123
# 80            Sales Representative        Av. Inês de Castro, 414
# 81                 Sales Associate              722 DaVinci Blvd.
# 82                   Sales Manager                  Smagsloget 45
# 83                     Sales Agent             2, rue du Commerce
# 84              Accounting Manager             59 rue de l'Abbaye
# 85            Sales Representative              Adenauerallee 900
# 86              Accounting Manager                    Torikatu 38
# 87                   Sales Manager             Rua do Mercado, 12
# 88                           Owner    305 - 14th Ave. S. Suite 3B
# 89       Owner/Marketing Assistant                  Keskuskatu 45
# 90                           Owner                ul. Filtrowa 68
#
#               city region postal_code      country              phone  \
# 0           Berlin   None       12209      Germany        030-0074321
# 1      México D.F.   None       05021       Mexico       (5) 555-4729
# 2      México D.F.   None       05023       Mexico       (5) 555-3932
# 3           London   None     WA1 1DP           UK     (171) 555-7788
# 4            Luleå   None    S-958 22       Sweden      0921-12 34 65
# 5         Mannheim   None       68306      Germany         0621-08460
# 6       Strasbourg   None       67000       France        88.60.15.31
# 7           Madrid   None       28023        Spain     (91) 555 22 82
# 8        Marseille   None       13008       France        91.24.45.40
# 9        Tsawassen     BC     T2F 8M4       Canada     (604) 555-4729
# 10          London   None     EC2 5NT           UK     (171) 555-1212
# 11    Buenos Aires   None        1010    Argentina       (1) 135-5555
# 12     México D.F.   None       05022       Mexico       (5) 555-3392
# 13            Bern   None        3012  Switzerland        0452-076545
# 14       Sao Paulo     SP   05432-043       Brazil      (11) 555-7647
# 15          London   None     WX1 6LT           UK     (171) 555-2282
# 16          Aachen   None       52066      Germany        0241-039123
# 17          Nantes   None       44000       France        40.67.88.88
# 18          London   None     WX3 6FW           UK     (171) 555-0297
# 19            Graz   None        8010      Austria          7675-3425
# 20       Sao Paulo     SP   05442-030       Brazil      (11) 555-9857
# 21          Madrid   None       28034        Spain     (91) 555 94 44
# 22           Lille   None       59000       France        20.16.10.16
# 23          Bräcke   None    S-844 67       Sweden      0695-34 67 21
# 24         München   None       80805      Germany        089-0877310
# 25          Nantes   None       44000       France        40.32.21.21
# 26          Torino   None       10100        Italy        011-4988260
# 27          Lisboa   None        1675     Portugal       (1) 354-2534
# 28       Barcelona   None       08022        Spain      (93) 203 4560
# 29         Sevilla   None       41101        Spain     (95) 555 82 82
# ..             ...    ...         ...          ...                ...
# 61       Sao Paulo     SP   05487-020       Brazil      (11) 555-1189
# 62       Cunewalde   None       01307      Germany        0372-035188
# 63    Buenos Aires   None        1010    Argentina       (1) 123-5555
# 64     Albuquerque     NM       87110          USA     (505) 555-5939
# 65   Reggio Emilia   None       42100        Italy        0522-556721
# 66  Rio de Janeiro     RJ   02389-890       Brazil      (21) 555-3412
# 67          Genève   None        1203  Switzerland        0897-034214
# 68          Madrid   None       28001        Spain      (91) 745 6200
# 69         Stavern   None        4110       Norway        07-98 92 35
# 70           Boise     ID       83720          USA     (208) 555-8097
# 71          London   None    OX15 4NB           UK     (171) 555-1717
# 72       Kobenhavn   None        1734      Denmark        31 12 34 56
# 73           Paris   None       75016       France    (1) 47.55.60.10
# 74          Lander     WY       82520          USA     (307) 555-4680
# 75       Charleroi   None      B-6000      Belgium  (071) 23 67 22 20
# 76        Portland     OR       97201          USA     (503) 555-3612
# 77           Butte     MT       59801          USA     (406) 555-5834
# 78         Münster   None       44087      Germany        0251-031259
# 79     México D.F.   None       05033       Mexico       (5) 555-2933
# 80       Sao Paulo     SP   05634-030       Brazil      (11) 555-2167
# 81        Kirkland     WA       98034          USA     (206) 555-8257
# 82           Århus   None        8200      Denmark        86 21 32 43
# 83            Lyon   None       69004       France        78.32.54.86
# 84           Reims   None       51100       France        26.47.15.10
# 85       Stuttgart   None       70563      Germany        0711-020361
# 86            Oulu   None       90110      Finland         981-443655
# 87         Resende     SP   08737-363       Brazil      (14) 555-8122
# 88         Seattle     WA       98128          USA     (206) 555-4112
# 89        Helsinki   None       21240      Finland        90-224 8858
# 90        Warszawa   None      01-012       Poland      (26) 642-7012
#
#                   fax
# 0         030-0076545
# 1        (5) 555-3745
# 2                None
# 3      (171) 555-6750
# 4       0921-12 34 67
# 5          0621-08924
# 6         88.60.15.32
# 7      (91) 555 91 99
# 8         91.24.45.41
# 9      (604) 555-3745
# 10               None
# 11       (1) 135-4892
# 12       (5) 555-7293
# 13               None
# 14               None
# 15     (171) 555-9199
# 16        0241-059428
# 17        40.67.89.89
# 18     (171) 555-3373
# 19          7675-3426
# 20               None
# 21     (91) 555 55 93
# 22        20.16.10.17
# 23               None
# 24        089-0877451
# 25        40.32.21.20
# 26        011-4988261
# 27       (1) 354-2535
# 28      (93) 203 4561
# 29               None
# ..                ...
# 61               None
# 62               None
# 63       (1) 123-5556
# 64     (505) 555-3620
# 65        0522-556722
# 66               None
# 67               None
# 68      (91) 745 6210
# 69        07-98 92 47
# 70               None
# 71     (171) 555-5646
# 72        31 13 35 57
# 73    (1) 47.55.60.20
# 74     (307) 555-6525
# 75  (071) 23 67 22 21
# 76               None
# 77     (406) 555-8083
# 78        0251-035695
# 79               None
# 80      (11) 555-2168
# 81     (206) 555-2174
# 82        86 22 33 44
# 83        78.32.54.87
# 84        26.47.15.11
# 85        0711-035428
# 86         981-443655
# 87               None
# 88     (206) 555-4115
# 89        90-224 8858
# 90      (26) 642-7012
#
# [91 rows x 11 columns]

# %% [markdown]
# **Prompt 1 Answer**:
#
# 91 Rows

# %% [markdown]
# ### Prompt 2
#
# If you sort the customers in alphabetical order by name, which customer is fourth?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT c.contact_name
FROM customers AS c
ORDER BY contact_name
"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#         contact_name
# 0   Alejandra Camino
# 1    Alexander Feuer
# 2  Anabela Domingues
# 3       Ana Trujillo
# 4      André Fonseca

# %% [markdown]
# **Prompt 2 Answer**:
#
# Ana Trujillo

# %% [markdown]
# ### Prompt 3
#
# Among those customers who live in Germany, if you sort the customers in alphabetical order by name, which customer is fourth?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT c.contact_name, c.country
FROM customers AS c
WHERE c.country = 'Germany'
ORDER BY c.contact_name

"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#           contact_name  country
# 0      Alexander Feuer  Germany
# 1           Hanna Moos  Germany
# 2  Henriette Pfalzheim  Germany
# 3          Horst Kloss  Germany
# 4        Karin Josephs  Germany

# %% [markdown]
# **Prompt 3 Answer**:
#
# Horst Kloss

# %% [markdown]
# ### Prompt 4
#
# From the `employees` table, what are the first names of the individuals who have a birthdate in the 1960s?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT e.first_name, e.birth_date
FROM employees AS e
WHERE e.birth_date BETWEEN '1960-01-01' and '1969-12-31'


"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#   first_name  birth_date
# 0      Janet  1963-08-30
# 1    Michael  1963-07-02
# 2     Robert  1960-05-29
# 3       Anne  1966-01-27

# %% [markdown]
# **Prompt 4 Answer**:
#
# Janet, Michael, Robert, Anne

# %% [markdown]
# ### Prompt 5
#
# In `order_details` table of the Northwind database, what is the total number of units sold for products 2, 3, and 4?
# > You should give us three numbers - one for each `ProductID`.

# %%
sql = """
Select od.product_id, SUM(od.quantity)
FROM order_details AS od
WHERE od.product_id BETWEEN '2' AND '4' 
GROUP BY od.product_id
ORDER BY od.product_id

"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    product_id   sum
# 0           2  1057
# 1           3   328
# 2           4   453

# %% [markdown]
# **Prompt 5 Answer**:
#
# >Product 2 units sold = 1057
# >
# >Product 3 units sold = 328
# >
# >Product 4 units sold = 453

# %% [markdown]
# ### Prompt 6
#
# From the `order_details` table of the Northwind database, calculate the revenue per product. In your SQL output, rename the revenue column `Revenue` and sort your results from largest revenue per product to smallest revenue per product. Which `ProductID` has the fifth-highest revenue, and what is that revenue rounded to the nearest dollar?
# > Note that revenue for a given product should be equal to the total unit price of that product times the quantity. You do not need to worry about the discount here. If you haven't multiplied columns together before, [this StackOverflow question](https://stackoverflow.com/questions/7536996/multiplying-two-columns-in-sql-server/7537059) may be helpful.

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT od.product_id, od.quantity * od.unit_price AS Revenue
FROM order_details AS od
ORDER BY Revenue DESC

"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    product_id       revenue
# 0          38  15810.000000
# 1          38  15810.000000
# 2          38  10540.000153
# 3          38  10540.000153
# 4          38  10540.000000

# %% [markdown]
# **Prompt 6 Answer**:
#
# > Product ID 38 has the 5th largest revenue at 10,540

# %% [markdown]
# ### Prompt 7
#
# From the `products` table of the Northwind database, show the `ProductName`, `UnitsInStock`, and `UnitsOnOrder` values for those products who have more units on order than units in stock. Among these results, which product has the most units on order?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT p.product_name, p.units_in_stock, p.units_on_order
FROM products AS p
WHERE p.units_on_order > p.units_in_stock
ORDER BY p.units_on_order DESC


"""

df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#                 product_name  units_in_stock  units_on_order
# 0  Louisiana Hot Spiced Okra               4             100
# 1  Wimmers gute Semmelknödel              22              80
# 2          Gorgonzola Telino               0              70
# 3                Rogede sild               5              70
# 4              Aniseed Syrup              13              70

# %% [markdown]
# **Prompt 7 Answer**:
#
# > Among these results, Louisiana Hot Spiced Okra has the most units on order

# %% [markdown]
# ### Prompt 8
#
# From the `order_details` table, show the products that have an average discount of at least 8%. Among these results, which average discount is closest to 8%?

# %%
sql = """
SELECT od.product_id, AVG(od.discount)
FROM order_details AS od
GROUP BY od.product_id
HAVING AVG(od.discount) >= 0.08
ORDER BY AVG(od.discount)DESC

"""

pd.read_sql_query(sql, engine)
# Out:
#    product_id       avg
# 0          48  0.108333
# 1           2  0.102273
# 2           9  0.100000
# 3          58  0.100000
# 4          25  0.086111
# 5          30  0.081250

# %% [markdown]
# **Prompt 8 Answer**:
#
# > Among these results, product ID # 30 has an average discount closest to 8%

# %% [markdown]
# ### Prompt 9
#
# Return the `orders` table, but also include the first name, last name, and country of the employee assigned to each order. What is the first and last name of the employee assigned to `OrderID` 11077? (This is the last row in the data, provided that you do not sort.)

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT o.*, e.last_name, e.first_name, e.country 
FROM orders AS o
INNER JOIN employees AS e on e.employee_id = o.employee_id
"""

df = pd.read_sql_query(sql, engine)
df.tail()
# Out:
#      order_id customer_id  employee_id  order_date required_date shipped_date  \
# 825     11073       PERIC            2  1998-05-05    1998-06-02         None
# 826     11074       SIMOB            7  1998-05-06    1998-06-03         None
# 827     11075       RICSU            8  1998-05-06    1998-06-03         None
# 828     11076       BONAP            4  1998-05-06    1998-06-03         None
# 829     11077       RATTC            1  1998-05-06    1998-06-03         None
#
#      ship_via  freight                   ship_name              ship_address  \
# 825         2    24.95   Pericles Comidas clásicas  Calle Dr. Jorge Cash 321
# 826         2    18.44               Simons bistro              Vinbæltet 34
# 827         2     6.19          Richter Supermarkt               Starenweg 5
# 828         2    38.28                    Bon app'      12, rue des Bouchers
# 829         2     8.53  Rattlesnake Canyon Grocery           2817 Milton Dr.
#
#        ship_city ship_region ship_postal_code ship_country last_name  \
# 825  México D.F.        None            05033       Mexico    Fuller
# 826    Kobenhavn        None             1734      Denmark      King
# 827       Genève        None             1204  Switzerland  Callahan
# 828    Marseille        None            13008       France   Peacock
# 829  Albuquerque          NM            87110          USA   Davolio
#
#     first_name country
# 825     Andrew     USA
# 826     Robert      UK
# 827      Laura     USA
# 828   Margaret     USA
# 829      Nancy     USA

# %% [markdown]
# **Prompt 9 Answer**:
#
# > First Name: Nancy
# >
# > Last Name: Davolio

# %% [markdown]
# ### Prompt 10
#
# Find the average amount of freight across all orders, broken out by country of *employee*. (**NOT `ShipCountry`**.) How much higher is the average freight from UK employees than the average freight from US employees?
#
# > For a bonus, round the freight to the nearest whole number and rename the column `Average Freight`.

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT AVG(o.freight) , e.country
FROM orders AS o
INNER JOIN employees AS e on e.employee_id = o.employee_id
GROUP BY e.country
"""

pd.read_sql_query(sql, engine)
# Out:
#          avg country
# 0  78.977143      UK
# 1  77.973284     USA

# %% [markdown]
# **Prompt 10 Answer**:
#
# > USA = 77.973284
# >
# > UK = 78.977143
# >
# > Difference = 1.003859
